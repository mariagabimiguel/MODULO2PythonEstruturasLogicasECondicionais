# %% [markdown]
# #Módulo 2 - Estruturas lógicas e Condicionais | Destravando Programação

# %% [markdown]
# ###Aplicação dos conceitos de estruturas lógicas e
# ###condicionais de Python em uma questão de
# ###Estatística do Vestibular da UNICAMP

# %% [markdown]
# ![imagem_2022-12-03_155151957.png](data:image/png;base64,...)

# %% [markdown]
# ###A ideia aqui é trabalhar com as alternativas.
#
# #####Então, como são poucos dados vamos digitar um por um e salvar em variáveis para serem trabalhadas usando as estruturas do estudo em questão: if, elif e else.

# %% [markdown]
# ###DADOS QUE RELACIONAM GÊNERO COM NÚMERO DE OBRAS NOS ANOS DE 2020 E 2021

# %%
romance_2020 = 35 
romance_2021 = 20 
romance_soma = romance_2020 + romance_2021
print (romance_soma)
# Out:
# 55

# %%
ficcao_2020 = 25 
ficcao_2021 = 35
ficcao_soma = ficcao_2020 + ficcao_2021
print (ficcao_soma)
# Out:
# 60

# %%
infantil_2020 = 30
infantil_2021 = 30
infantil_soma = infantil_2020 + infantil_2021
print (infantil_soma)
# Out:
# 60

# %%
tecnologia_2020 = 10
tecnologia_2021 = 20 
tecnologia_soma = tecnologia_2020 + tecnologia_2021 
print (tecnologia_soma)
# Out:
# 30

# %%
biografias_2020 = 30 
biografias_2021 = 30
biografias_soma = biografias_2020 + biografias_2021
print (biografias_soma)
# Out:
# 60

# %% [markdown]
# ##Agora vamos as analises para encontrar a alternativa correta
#
# ###Precisamos definir:
#
# * O gênero com maior quantidade vendida:
#
# mais_vendida = ['biografias_soma', 'ficccao_soma', 'infantil_soma']
#
# * Gênero que teve menos obras vendidas:
#
# menos_vendida = tecnologia_soma
#
# * Gêneros que venderam mais obras em 2021 quando em comparação com as vendas de 2020
#
# para isso, vamos criar condições para cada obra e analisar em quais o valor do ano de 2021 é maior que o de 2020 e salvar em uma variável para termos o controle de quais satisfazem a condição
#
#
#
# * Valor do dobro de vendas de obras de romance em 2020 para comparar:
#
# condicao_c = (2*romance_2020)
#
#
#
# * Soma dos anos da obra Infantil e Soma dos dois anos do gênero Biografias (já definido da parte dos dados)

# %% [markdown]
# #ALTERNATIVAS

# %% [markdown]
# # **A)**

# %%
mais_vendida = ['biografias_soma', 'ficccao_soma', 'infantil_soma']

# %%
menos_vendida = tecnologia_soma

# %%
condicao_a = (3*menos_vendida)

# %%
if ((biografias_soma == mais_vendida) and (biografias_soma == condicao_a)):
    print ("Alternativa Correta")
else:
    print ("Alternativa Falsa")
# Out:
# Alternativa Falsa

# %% [markdown]
# # **B)**

# %%
condicao_b1 = ""
condicao_b2 = ""
condicao_b3 = ""

# %%
if (romance_2021 > romance_2020):
    condicao_b1 = "Romance"

# %%
if (ficcao_2021 > ficcao_2020):
     if (condicao_b1 == "Romance"):
       condicao_b2 = "Ficcao"
     else:
       condicao_b1 = "Ficcao"

# %%
if (infantil_2021 > infantil_2020):
    if (condicao_b1 == "Ficcao"):
           condicao_b2 = "Infantil"
    else:
           condicao_b1 = "Infantil"

# %%
if (tecnologia_2021 > tecnologia_2020):
             if (condicao_b2 == "Infantil"):
              condicao_b3 = "Tecnologia"
             else: 
               condicao_b2 = "Tecnologia"

# %%
    if (biografias_2021 > biografias_2020):
                    if (condicao_b2 == "Tecnologia"):
                      condicao_b3 = "Biografia"
                    else: 
                      condicao_b2 = "Biografia"

# %%
print (condicao_b1)
# Out:
# Ficcao

# %%
print (condicao_b2)
# Out:
# Tecnologia

# %%
print (condicao_b3)

# %%
if (((condicao_b1 or condicao_b2 or condicao_b3) == "Ficcao") and ((condicao_b1 or condicao_b2 or condicao_b3) == "Infantil")):
     print ("Alternativa Correta")
else:
     print ("Alternativa Falsa")
# Out:
# Alternativa Falsa

# %% [markdown]
# # **C)**

# %%
condicao_c = (2*romance_2020)

# %%
if (romance_2021 == condicao_c):
  print ("Alternativa Correta")
else: print ("Alternativa Falsa")
# Out:
# Alternativa Falsa

# %% [markdown]
# # **D)**

# %%
if (biografias_soma) == (infantil_soma):
  print ("Alternativa Correta")
else: print ("Alternativa Falsa")
# Out:
# Alternativa Correta
